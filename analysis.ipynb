# %% [markdown]
# Importing the modules

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Portofilo\titanic\data\procesed.csv")
print(df.head(10))
print("**"*40)
print(df.tail(10))
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass                   Name     Sex  \
# 0           0            1         0       3        Mr. Owen Harris    male
# 1           1            2         1       1      Mrs. John Bradley  female
# 2           2            3         1       3            Miss. Laina  female
# 3           3            4         1       1     Mrs. Jacques Heath  female
# 4           4            5         0       3      Mr. William Henry    male
# 5           5            6         0       3              Mr. James    male
# 6           6            7         0       1          Mr. Timothy J    male
# 7           7            8         0       3  Master. Gosta Leonard    male
# 8           8            9         1       3           Mrs. Oscar W  female
# 9           9           10         1       2          Mrs. Nicholas  female
#
#         Age  SibSp  Parch            Ticket     Fare     Embarked
# 0  22.00000      1      0         A/5 21171   7.2500  Southampton
# ...
